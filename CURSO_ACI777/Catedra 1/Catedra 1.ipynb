# %%
import pandas as pd
import numpy as np
import pprint

# %%
df = pd.read_csv('data/codon_usage.csv', index_col = 0) 
df
# Out:
# C:\Users\Bruno\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          DNAtype  SpeciesID   Ncodons  \
# Kingdom
# vrl            0     100217      1995
# vrl            0     100220      1474
# vrl            0     100755      4862
# vrl            0     100880      1915
# vrl            0     100887     22831
# ...          ...        ...       ...
# pri            0       9601      1097
# pri            1       9601      2067
# pri            1       9602      1686
# pri            0       9606  40662582
# pri            1       9606   8998998
#
#                                      SpeciesName      UUU      UUC      UUA  \
# Kingdom
# vrl      Epizootic haematopoietic necrosis virus  0.01654  0.01203  0.00050
# vrl                             Bohle iridovirus  0.02714  0.01357  0.00068
# ...

# %%
lp=df.head(2)

# %%
lp.mean()
# Out:
# DNAtype           0.000000
# SpeciesID    100218.500000
# Ncodons        1734.500000
# UUA               0.000590
# UUG               0.005145
#                  ...
# GAA               0.013815
# GAG               0.043855
# UAA               0.002610
# UAG               0.000590
# UGA               0.000000
# Length: 65, dtype: float64

# %%
df.mean(axis=1)
# Out:
# Kingdom
# vrl      1572.507253
# vrl      1564.537835
# vrl      1624.891668
# vrl      1581.476305
# vrl      1903.368586
#            ...
# pri       164.599060
# pri       179.537777
# pri       173.691578
# pri    625725.984033
# pri    138593.937615
# Length: 13028, dtype: float64

# %%
df.std()
# Out:
# DNAtype           0.688726
# SpeciesID    124787.086107
# Ncodons      719700.970711
# UUA               0.020709
# UUG               0.009280
#                  ...
# GAA               0.014342
# GAG               0.015018
# UAA               0.001834
# UAG               0.000907
# UGA               0.010344
# Length: 65, dtype: float64

# %%
df.var()
# Out:
# DNAtype      4.743434e-01
# SpeciesID    1.557182e+10
# Ncodons      5.179695e+11
# UUA          4.288585e-04
# UUG          8.611456e-05
#                  ...
# GAA          2.057044e-04
# GAG          2.255274e-04
# UAA          3.362062e-06
# UAG          8.221911e-07
# UGA          1.070042e-04
# Length: 65, dtype: float64
